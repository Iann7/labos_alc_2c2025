# %% [markdown]
# # Ejercicio 6
#
# A continuacion elaboramos en tres archivos distintos la matriz de confusion para cada uno de los metodos planteados. Las conclusiones para cada uno estan en sus respectivos archivos (ej6QR, ej6Cholesky, ej6SVD).

# %%
# Ejercicio 7 
A lo largo del trabajo practico implementacion diferentes metodos para procesar imagenes de perros y gatos.
Esta "cabeza" del modelo de clasificacion convolucional la elaboramos con 3 algoritmos diferentes basados en diferentes metodos de factorizacion que vimos en la cursada.

Los resultados fueron similares entre cada una de nuestras implementaciones. Lo que podemos observar en cada matriz de confusion es que hay una ponderacion bastante elevada a seleccion de gatos,
 y aunque el hitrate en perros es inferior, terminamos teniendo un hitrate promedio de alrededor de 63%.


QR y Cholesky dieron los mismos resultados tanto en gatos como perros con 63% de hitrate total. Pero la diferencia entre ellos radica en el tiempo que tardo cada algoritmo. Cholesky se demoro 95 minutos y QR 38 minutos.

Por otro lado SVD directamente no logramos hacerlo correr con todas las imagenes por lo mucho que tardaba. 
Hicimos una funcion auxiliar "reducir_matrices_testeo" dentro de alc.py con la que recortamos la cantidad de imagenes de forma de que se entrene con menos, y tarde menos.
