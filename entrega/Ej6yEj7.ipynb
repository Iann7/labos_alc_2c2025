# %% [markdown]
# ### Nombre de grupo: Factorización A=Libreta Universitaria
# # Integrantes del grupo
# - Francisco Rabito LU: 1687/21
# - Pedro Sanchez LU: 1140/22
# - Santiago Manjarin LU: 616/22
# - Ignacio Giuiliano Iannello 183/23

# %% [markdown]
# # Ejercicio 6
#
# A continuación elaboramos en tres archivos distintos la matriz de confusión para cada uno de los métodos planteados. Las conclusiones para cada uno están en sus respectivos archivos (ej6QR, ej6Cholesky, ej6SVD).
#
# La división en varios notebooks fue hablada previamente con profesores de la cátedra. La intención de esto era poder correr cada notebook en paralelo, siendo que son algoritmos costosos temporalmente.

# %% [markdown]
# # Ejercicio 7
# A lo largo del trabajo práctico implementamos diferentes métodos para procesar imágenes de perros y gatos.
# Esta "cabeza" del modelo de clasificación convolucional la elaboramos con 3 algoritmos diferentes basados en diferentes métodos de factorización que vimos en la cursada.
#
# Los resultados fueron similares en términos de hit rate. Lo que podemos observar en la matriz de confusión de QR y Cholesky es que hay una ponderación bastante elevada a la selección de gatos,
# y aunque el hitrate en perros es inferior, terminamos teniendo un hitrate promedio de 63.2%. Esto cambia con SVD (con 100 imágenes), donde podemos ver que da un resultado más balanceado entre perros y gatos y un hitrate marginalmente mejor de 63.8%.
#
# Pero la diferencia entre ellos radica en el tiempo que tardó cada algoritmo. Cholesky se demoró 95 minutos y QR 38 minutos, procesando ambos con todas las imágenes. En el caso de SVD,
# no logramos correrlo con todas las imágenes, ya que tardaba demasiado. Llegamos a correrlo por más de 800 minutos sin que dé un resultado.
# Por esto mismo utilizamos una función que recorta la cantidad de imágenes para obtener resultados. Aunque lo corrimos con tan solo 100 imágenes, se demoró 36 minutos en correr.
#
# A pesar de esto, terminó dando resultados marginalmente mejores que QR y Cholesky en torno al hitrate.
#
# Las matrices de confusión de QR y Cholesky devuelven:
#
# [433,  67]
#
# [301, 199]
#
# En esto podemos ver cómo su performance adivinando gatos es muy alta, con un 86.6% de hitrate.
# En cambio, con los perros es bastante mala, dando un 39.8%.
# Las matrices de confusión de SVD devuelven:
#
# [332,  168]
#
# [194, 306]
#
# En este caso tenemos una performance mejor al 50% en ambos casos.
# En gatos podemos ver un 66.4% y en perros 61.2%.
