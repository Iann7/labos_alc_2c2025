# %% [markdown]
# # Ejercicio 6 SVD
#
# Estos son los resultados de nuestra matriz de confusion con SVD

# %%
# Imports necesarios
import numpy as np
import matplotlib.pyplot as plt
from alc import *
from auxiliaresEj6 import * # Funciones auxiliares para este ejercicio
path_base = "../cats_and_dogs"
X_t, Y_t, X_v, Y_v = cargarDataset(path_base) # Siendo _t nuestros modelos de training (entrenamiento) y _v de validation (validacion)
calcularYPlotearMatrizDeConfusion(X_t, Y_t, X_v, Y_v, metodo="SVD")
# Out:
# Reduciendo matrices de entrenamiento a 100 ejemplos por clase
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 8
#       6 path_base = "../cats_and_dogs"
#       7 X_t, Y_t, X_v, Y_v = cargarDataset(path_base) # Siendo _t nuestros modelos de training (entrenamiento) y _v de validation (validacion)
# ----> 8 calcularYPlotearMatrizDeConfusion(X_t, Y_t, X_v, Y_v, metodo="SVD")
#
# File ~/Documents/alc/entrega/auxiliaresEj6.py:55, in calcularYPlotearMatrizDeConfusion(X_t, Y_t, X_v, Y_v, metodo)
#      53     W = fullyConnectedLineal_QR(X_t, Y_t)
#      54 elif metodo == "SVD":
# ---> 55     W = fullyConnectedLineal_SVD(X_t, Y_t)
#      56 else:
#      57     raise ValueError("Método no reconocido. Usar 'Cholesky', 'QR' o 'SVD'.")
#
# File ~/Documents/alc/entrega/alc.py:1519, in fullyConnectedLineal_SVD(X, Y)
#    1517 n,_ = X.shape
#    1518 U_de_x,Sigma_de_x,V_de_x = svd_reducida(X,k=n)
# -> 1519 return pinvSVD(U_de_x, Sigma_de_x, V_de_x,Y)
#
# File ~/Documents/alc/entrega/alc.py:1524, in pinvSVD(U, S, V, Y)
#    1523 def pinvSVD(U:np.ndarray,S:np.ndarray,V:np.ndarray,Y:np.ndarray):
# -> 1524     Ur, Sr, Vr = reducirSVD(U, S, V)
#    1525     Ur_traspuesta = traspuesta(Ur)
#    1526     Sr_inversa = list_to_diag(1.0 / Sr)
#
# File ~/Documents/alc/entrega/alc.py:1533, in reducirSVD(U, S, V, atol)
#    1531 def reducirSVD(U:np.ndarray, S:np.ndarray, V:np.ndarray, atol=1e08):
#    1532     cantidad_de_rs = 0
# -> 1533     n = min(S.shape[0], S.shape[1])
#    1534     for i in range(n):
#    1535         if allclose(0, S[i,i], atol):
#
# IndexError: tuple index out of range
