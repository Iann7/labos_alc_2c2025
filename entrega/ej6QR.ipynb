# %% [markdown]
# # Ejercicio 6 QR
#
# Estos son los resultados de nuestra matriz de confusion con QR

# %%
# Imports necesarios
import numpy as np
import matplotlib.pyplot as plt
from alc import *
from auxiliaresEj6 import * # Funciones auxiliares para este ejercicio
path_base = "../cats_and_dogs"
X_t, Y_t, X_v, Y_v = cargarDataset(path_base) # Siendo _t nuestros modelos de training (entrenamiento) y _v de validation (validacion)
calcularYPlotearMatrizDeConfusion(X_t, Y_t, X_v, Y_v, metodo="QR")
# Out:
# FINALIZO QR
# Hitrate gato 0.668 siendo 334.0 de 500.0 gatos correctamente clasificados
# Hitrate perro 0.7 siendo 350.0 de 500.0 perros correctamente clasificados
# Hitrate total 0.684
